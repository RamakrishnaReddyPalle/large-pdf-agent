# %%
from pathlib import Path
import sys, os, platform

CWD  = Path.cwd().resolve()
ROOT = CWD if (CWD / "src").exists() else CWD.parent
if str(ROOT) not in sys.path: sys.path.append(str(ROOT))

# %%
from src.nys_mfs_agent.ui import start_app, launch_app
demo = start_app()
launch_app(demo, server_name="127.0.0.1", preferred_port=7860, share=False)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Exception in thread Thread-11 (run_loop):
# Traceback (most recent call last):
#   File "d:\Anaconda\envs\pdf-agent-2\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "d:\Anaconda\envs\pdf-agent-2\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "d:\Anaconda\envs\pdf-agent-2\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "D:\IIT BBS\Job Resources\Business Optima\pdf-agent\src\nys_mfs_agent\ui.py", line 159, in run_loop
#     asyncio.run(runner())
#   File "d:\Anaconda\envs\pdf-agent-2\Lib\asyncio\runners.py", line 190, in run
#     return runner.run(main)
# ...

# %%
import importlib
import src.nys_mfs_agent.logger as _logger
import src.nys_mfs_agent.orchestrator as _orch
import src.nys_mfs_agent.multi_orchestrator as _morch

importlib.reload(_logger)
importlib.reload(_orch)
importlib.reload(_morch)
# Out:
# <module 'src.nys_mfs_agent.multi_orchestrator' from 'D:\\IIT BBS\\Job Resources\\Business Optima\\pdf-agent\\src\\nys_mfs_agent\\multi_orchestrator.py'>

# %%
from src.nys_mfs_agent.multi_orchestrator import MultiAgent
from src.nys_mfs_agent.logger import SessionLogger

ma = MultiAgent()
log = SessionLogger()

import asyncio
async def quick(q: str):
    print("User:", q)
    print("Assistant:", end=" ", flush=True)
    async for tok in ma.ask(q, logger=log):
        print(tok, end="", flush=True)
    print("\n\nLog file:", log._path)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
await quick("Give 3 bullets on Physical Medicine reimbursement limits.")
# Out:
# User: Give 3 bullets on Physical Medicine reimbursement limits.
# Assistant: { "short": "For physical medicine services, if multiple procedures and/or modalities are provided on the same day, reimbursement is limited to 12.0 RVUs per patient per accident or illness or the amount billed, whichever is lesser. If treatments vary based on medical treatment guidelines adopted by the Chair of the Workers' Compensation Board, those guidelines will prevail.{'type': 'final', 'text': ''}
#
# Log file: D:\IIT BBS\Job Resources\Business Optima\pdf-agent\data\runs\New_York_State_Workers_Compensation_Medical_Fee\sessions\logs\session_1756717134089.jsonl

# %%
await quick("What is the latest Premier League table?")
# Out:
# User: What is the latest Premier League table?
# Assistant: Sorry—I can only answer questions about the OFFICIAL NEW YORK STATE WORKERS’ COMPENSATION – MEDICAL FEE SCHEDULE. Please ask about rules, sections, coding, billing, or documentation from this fee schedule.
#
# Log file: D:\IIT BBS\Job Resources\Business Optima\pdf-agent\data\runs\New_York_State_Workers_Compensation_Medical_Fee\sessions\logs\session_1756713996689.jsonl

# %%
await quick("What documentation is required for Evaluation and Management visits?")
# Out:
# User: What documentation is required for Evaluation and Management visits?
# ...

# %%
await quick("Summarize billing rules in the Introduction and General Guidelines; and also tell me the RVU cap for multiple physical medicine modalities in one day.")
# Out:
# User: Summarize billing rules in the Introduction and General Guidelines; and also tell me the RVU cap for multiple physical medicine modalities in one day.
# Assistant:
# ### Part 1/2: Summarize billing rules in the Introduction and General Guidelines?
# ...
